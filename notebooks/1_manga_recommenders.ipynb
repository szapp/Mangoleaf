# %%
import pandas as pd

# %% [markdown]
# # **MANGA DATASET**

# %%
# author is missing in this dataset
# I could combine this dataset with another one I have which has the author included (but only around 160 mangas)

# %%
file_path = '../data/mangas/raw/anime-dataset-2023.csv'

df_manga = pd.read_csv(file_path)

df_manga.head(5)
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
df_manga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
# ...

# %% [markdown]
# # **DATA CLEANING**

# %%
#decided to drop a few columns that I do not need

df_manga_new=df_manga.drop(['Status','Aired','Licensors','Rating','Producers','Episodes','Duration','Synopsis'],axis=1)

# %%
#I am dropping everything that is not an anime series (makes more sense because series = manga)

distinct_titles = df_manga_new['Type'].unique()

print(distinct_titles)
# Out:
# ['TV' 'Movie' 'OVA' 'Special' 'ONA' 'Music' 'UNKNOWN']

# %%
values_to_drop = ['Movie', 'OVA', 'Special', 'ONA', 'Music', 'Unknown']

df_manga2 = df_manga_new[~df_manga_new['Type'].isin(values_to_drop)]

# %%
df_manga2.describe()
# Out:
#            anime_id    Popularity      Favorites       Members
# count   7671.000000   7671.000000    7671.000000  7.671000e+03
# mean   28711.789467  11094.563681    1234.236866  9.170881e+04
# std    18706.301703   8666.109832    7584.487023  2.606770e+05
# min        1.000000      0.000000       0.000000  0.000000e+00
# 25%     7723.500000   2738.000000       0.000000  8.300000e+01
# 50%    34636.000000   9439.000000       6.000000  2.865000e+03
# 75%    45923.000000  20763.000000     180.000000  5.357550e+04
# max    55727.000000  24637.000000  217606.000000  3.744541e+06

# %%
#again I am dropping all animes that do not have an english name because it makes more sense for the app

values_to_drop2 = ['Unknown','UNKNOWN']

df_manga2 = df_manga2[~df_manga2['English name'].isin(values_to_drop2)]

# %%
#decided to replace all unknown "Scores" to 0 and make them into a float

 #Replace 'unknown' with '0' in the 'Score' column
df_manga2['Score'] = df_manga2['Score'].replace('UNKNOWN', '0')

# Convert 'Score' column to float
df_manga2['Score'] = pd.to_numeric(df_manga2['Score'])

df_manga2
df_manga2.dtypes  # To check the data types of the columns
# Out:
# anime_id          int64
# Name             object
# English name     object
# Other name       object
# Score           float64
# Genres           object
# Type             object
# Premiered        object
# Studios          object
# Source           object
# Rank             object
# Popularity        int64
# Favorites         int64
# Scored By        object
# Members           int64
# Image URL        object
# dtype: object

# %%
rating_count_df = df_manga2.groupby('English name')['Score'].agg(['mean']).reset_index()
rating_count_df.nlargest(20, ['mean'])
# Out:
#                                      English name  mean
# 1022             Fullmetal Alchemist: Brotherhood  9.10
# 397               Bleach: Thousand-Year Blood War  9.07
# 2960                                  Steins;Gate  9.07
# 1134                             Gintama Season 4  9.06
# 241               Attack on Titan Season 3 Part 2  9.05
# 1577    Kaguya-sama: Love is War - Ultra Romantic  9.05
# 1133                             Gintama Season 2  9.04
# 1139                           Gintama: Enchousen  9.03
# 1008              Fruits Basket: The Final Season  9.00
# 1135                             Gintama Season 5  8.98
# 3812                                 [Oshi No Ko]  8.98
# 1132                                      Gintama  8.94
# 608                          Clannad: After Story  8.93
# 1955        March Comes In Like A Lion 2nd Season  8.93
# 626       Code Geass: Lelouch of the Rebellion R2  8.91
# 1137  Gintama.: Silver Soul Arc - Second Half War  8.88
# ...

# %%
# again decided to Replace 'unknown' with '0' in the 'Ranked' column and make them into a numeric
df_manga2['Rank'] = df_manga2['Rank'].replace('UNKNOWN', '0')

df_manga2['Rank'] = pd.to_numeric(df_manga2['Rank'])

# %%
top_10_ranked = df_manga2.sort_values(by='Rank').head(10)

# %%
#dropping all ranked animes with 0 for better use
df_manga2 = df_manga2[df_manga2['Rank'] != 0.0]

# %%
import re

# %%
# I want to delete some words so every manga is only once in the list
# Extract main series name using regex
df_manga2['Main_series'] = df_manga2['English name'].apply(lambda x: re.split(r'[:Season ]', x)[0])

# %%
# Define words/phrases to remove
remove_words = [
'Season 2', 'Final Season', 'Season 3', 'Season 4', 'Season 5',
'Season 6', '3rd Season', 'Second Season', '2nd Season','Part 2'
]

# Create regex pattern
pattern = '|'.join(remove_words)

# Remove words/phrases from 'English name'
df_manga2['English name'] = df_manga2['English name'].str.replace(pattern, '', regex=True).str.strip()

# %% [markdown]
# # **Popularity recommender for Manga**

# %%
# hybrid recommendation model with Score and Ranked

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Extract main series name using regex
df_manga2['Main_series'] = df_manga2['English name'].apply(lambda x: re.split(r'[:Season ]', x)[0])

# I Normalized 'Ranked' and 'Score' columns with minmaxscaler
scaler = MinMaxScaler()
df_manga2[['Ranked_normalized', 'Score_normalized']] = scaler.fit_transform(df_manga2[['Rank', 'Score']])

# Invert the normalized rank so that higher ranks (closer to 1) have higher normalized values
df_manga2['Ranked_normalized'] = 1 - df_manga2['Ranked_normalized']

# Combine the normalized 'Ranked' and 'Score' into a single metric
df_manga2['Combined_metric'] = df_manga2['Ranked_normalized'] + df_manga2['Score_normalized']

 # Group by 'English name' and get the row with the highest rank (lowest 'Ranked' value)
idx = df_manga2.groupby('Main_series')['Rank'].idxmin()
df_unique = df_manga2.loc[idx]

# Get the top recommendations based on the combined metric
top_recommendations = df_unique.sort_values(by='Combined_metric', ascending=False).head(10)

print(top_recommendations[['English name', 'Rank', 'Score', 'Combined_metric']])
# Out:
#                                     English name  Rank  Score  Combined_metric
# 3961            Fullmetal Alchemist: Brotherhood   1.0   9.10         2.000000
# 16617            Bleach: Thousand-Year Blood War   2.0   9.07         1.996654
# 5667                                 Steins;Gate   3.0   9.07         1.996604
# 9880                                     Gintama   4.0   9.06         1.995455
# 17572  Kaguya-sama: Love is War - Ultra Romantic   5.0   9.05         1.994306
# 14865                            Attack on Titan   6.0   9.05         1.994257
# 6456                             Hunter x Hunter  10.0   9.04         1.992959
# 17216                         Fruits Basket: The  13.0   9.00         1.988414
# 22622                               [Oshi No Ko]  14.0   8.98         1.986166
# 12829                 March Comes In Like A Lion  18.0   8.93         1.980473

# %%
# my task is to create a function that takes an input ‘n’ (n is an integer, how many mangas I wish to display)
# and outputs the top n movies so that I can populate the first row of most popular mangas for our APP
def get_top_n_mangas(df, n):
    top_recommendations = df_unique.sort_values(by='Combined_metric', ascending=False).head(n)

    return top_recommendations[['anime_id','Genres','English name','Other name', 'Rank', 'Score', 'Combined_metric']]

# Example
n = 10
top_n_mangas = get_top_n_mangas(df_manga, n)

# %% [markdown]
# # **Model training (collaborative filtering)**

# %%
# !pip install wordcloud -q

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import warnings
warnings.filterwarnings(action='ignore')
import os
from sklearn.preprocessing import LabelEncoder

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf

from keras.api._v2.keras.layers import Input, Embedding, Dot, Flatten, Dense
from keras.api._v2.keras.models import Model
from keras.api._v2.keras.optimizers import Adam
from wordcloud import WordCloud
from collections import defaultdict
from collections import Counter

# %%
file_path_manga = '/content/drive/My Drive/anime-dataset-2023.csv'
df_manga = pd.read_csv(file_path_manga)

# %%
file_path = '/content/drive/My Drive/users-score-2023.csv'

df_score = pd.read_csv(file_path)

df_score
# Out:
#           user_id    Username  anime_id             Anime Title  rating
# 0               1       Xinil        21               One Piece       9
# 1               1       Xinil        48             .hack//Sign       7
# 2               1       Xinil       320                  A Kite       5
# 3               1       Xinil        49        Aa! Megami-sama!       8
# 4               1       Xinil       304  Aa! Megami-sama! Movie       8
# ...           ...         ...       ...                     ...     ...
# 24325186  1291087   Oblongata     10611                    R-15       3
# 24325187  1291087   Oblongata       174            Tenjou Tenge       6
# 24325188  1291097  JuunanaSai      1535              Death Note       9
# 24325189  1291097  JuunanaSai       226              Elfen Lied      10
# 24325190  1291097  JuunanaSai      8425                  Gosick      10
#
# [24325191 rows x 5 columns]

# %%
#df_score = df_score.sample(n=1000000, random_state=42)

# %%
# Calculating the average score
avg_score = np.mean(df_score['rating'])
print('Average Score:', avg_score)
# Out:
# Average Score: 7.622930072779285

# %%
# Scaling my "rating" column
# Create a MinMaxScaler object
scaler = MinMaxScaler(feature_range=(0, 1))

# Scale the 'score' column between 0 and 1
df_score['scaled_score'] = scaler.fit_transform(df_score[['rating']])

# %%
# Encoding categorical data

## Encoding user IDs
user_encoder = LabelEncoder()
df_score["user_encoded"] = user_encoder.fit_transform(df_score["user_id"])
num_users = len(user_encoder.classes_)

## Encoding anime IDs
manga_encoder = LabelEncoder()
df_score["manga_encoded"] = manga_encoder.fit_transform(df_score["anime_id"])
num_manga = len(manga_encoder.classes_)

# Printing dataset information
print("Number of unique users: {}, Number of unique manga: {}".format(num_users, num_manga))
print("Minimum rating: {}, Maximum rating: {}".format(min(df_score['rating']), max(df_score['rating'])))
# Out:
# Number of unique users: 270033, Number of unique manga: 16500
# Minimum rating: 1, Maximum rating: 10

# %%
# Shuffle the dataset
df_score = shuffle(df_score, random_state=100)

# Create feature matrix X and target variable y
X = df_score[['user_encoded', 'manga_encoded']].values
y = df_score["scaled_score"].values

# Printing dataset information
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (24325191, 2)
# Shape of y: (24325191,)

# %%
test_set_size = 10000  # Number of samples to include in the test set

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_set_size, random_state=73)

print("Number of samples in the training set:", len(y_train))
print("Number of samples in the test set:", len(y_test))
# Out:
# Number of samples in the training set: 24315191
# Number of samples in the test set: 10000

# %%
# Prepare input data for model training and evaluation
X_train_array = [X_train[:, 0], X_train[:, 1]]
X_test_array = [X_test[:, 0], X_test[:, 1]]

# %%
tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
print('Running on TPU ', tpu.cluster_spec().as_dict())
# Out:
# Running on TPU  {}

# %%
 #No TPU initialization required, default to CPU/GPU
#try:
#    # Use GPU if available, otherwise fall back to CPU
#    gpus = tf.config.list_physical_devices('GPU')
#    if gpus:
#        strategy = tf.distribute.MirroredStrategy()
#    else:
#        strategy = tf.distribute.get_strategy()  # Default strategy that works on CPU
#except Exception as e:
#    print(e)

# Setting TPU_INIT flag
USE_TPU = True

# Checking if TPU is initialized
if USE_TPU:
    # If tpu is connected then start creating TPUStrategy
    resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='local')
    tf.tpu.experimental.initialize_tpu_system(resolver)
    strategy = tf.distribute.TPUStrategy(resolver)
else:
    # !nvidia-smi

# Print the TensorFlow version
tf_version = tf.__version__
print(f"TensorFlow version: {tf_version}")
# Out:
# TensorFlow version: 2.15.0

# %%
def RecommenderNet(num_users, num_manga, embedding_size=128):
    # User input layer and embedding layer
    user = Input(name='user_encoded', shape=[1])
    user_embedding = Embedding(name='user_embedding', input_dim=num_users, output_dim=embedding_size)(user)

    # Anime input layer and embedding layer
    manga = Input(name='manga_encoded', shape=[1])
    manga_embedding = Embedding(name='manga_embedding', input_dim=num_manga, output_dim=embedding_size)(manga)

    # Dot product of user and anime embeddings
    dot_product = Dot(name='dot_product', normalize=True, axes=2)([user_embedding, manga_embedding])
    flattened = Flatten()(dot_product)

    # Dense layers for prediction
    dense = Dense(64, activation='relu')(flattened)
    output = Dense(1, activation='sigmoid')(dense)

    # Create and compile the model
    model = Model(inputs=[user, manga], outputs=output)
    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=["mae", "mse"])

    return model

# Check if GPU is available and create the model accordingly
#physical_devices = tf.config.list_physical_devices('GPU')
#if physical_devices:
#    tf.config.experimental.set_memory_growth(physical_devices[0], True)
#    strategy = tf.distribute.MirroredStrategy()
#else:
#    strategy = tf.distribute.get_strategy()

#with strategy.scope():
#    model = RecommenderNet(num_users, num_manga)

# Print model summary
#model.summary()

# Checking if TPU is initialized and create the model accordingly
if USE_TPU:
    with strategy.scope():
        model = RecommenderNet(num_users, num_manga)
else:
    model = RecommenderNet(num_users, num_manga)

 #Printing my model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  user_encoded (InputLayer)   [(None, 1)]                  0         []
#
#  manga_encoded (InputLayer)  [(None, 1)]                  0         []
#
#  user_embedding (Embedding)  (None, 1, 128)               3456422   ['user_encoded[0][0]']
#                                                           4
#
#  manga_embedding (Embedding  (None, 1, 128)               2112000   ['manga_encoded[0][0]']
#  )
#
#  dot_product (Dot)           (None, 1, 1)                 0         ['user_embedding[0][0]',
#                                                                      'manga_embedding[0][0]']
#
#  flatten (Flatten)           (None, 1)                    0         ['dot_product[0][0]']
#
#  dense (Dense)               (None, 64)                   128       ['flatten[0][0]']
#
# ...

# %% [markdown]
# # **Item Based Recommmender**

# %%
## Import necessary callbacks
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping

# Define the initial learning rate, minimum learning rate, maximum learning rate, and batch size
start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005
batch_size = 10000

# Adjust the maximum learning rate and batch size if using TPU
if USE_TPU:
    max_lr = max_lr * strategy.num_replicas_in_sync
    batch_size = batch_size * strategy.num_replicas_in_sync

# Define the number of epochs for ramp-up, sustain, and exponential decay
rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8

# Learning rate schedule function
def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr) / rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch - rampup_epochs - sustain_epochs) + min_lr
# Learning rate scheduler callback
lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=0)

# File path for saving the model weights
checkpoint_filepath = '/kaggle/working/myanimeweights.h5'

# Model checkpoint callback to save the best weights
model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                    save_weights_only=True,
                                    monitor='val_loss',
                                    mode='min',
                                    save_best_only=True)

# Early stopping callback to prevent overfitting
early_stopping = EarlyStopping(patience=3, monitor='val_loss', mode='min', restore_best_weights=True)

# Define the list of callbacks
my_callbacks = [
    model_checkpoints,
    lr_callback,
    early_stopping
]

# %%
# Model training
history = model.fit(
    x=X_train_array,
    y=y_train,
    batch_size=batch_size,
    epochs=20,
    verbose=1,
    validation_data=(X_test_array, y_test),
    callbacks=my_callbacks
)

model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/20
# 304/304 [==============================] - 24s 48ms/step - loss: 0.6898 - mae: 0.2606 - mse: 0.0880 - val_loss: 0.6875 - val_mae: 0.2581 - val_mse: 0.0865 - lr: 1.0000e-05
# Epoch 2/20
# 304/304 [==============================] - 8s 26ms/step - loss: 0.6648 - mae: 0.2372 - mse: 0.0756 - val_loss: 0.6398 - val_mae: 0.2128 - val_mse: 0.0628 - lr: 8.8000e-05
# Epoch 3/20
# 304/304 [==============================] - 8s 26ms/step - loss: 0.6048 - mae: 0.1768 - mse: 0.0465 - val_loss: 0.5827 - val_mae: 0.1520 - val_mse: 0.0359 - lr: 1.6600e-04
# Epoch 4/20
# 304/304 [==============================] - 8s 26ms/step - loss: 0.5784 - mae: 0.1483 - mse: 0.0345 - val_loss: 0.5769 - val_mae: 0.1459 - val_mse: 0.0335 - lr: 2.4400e-04
# Epoch 5/20
# 304/304 [==============================] - 8s 26ms/step - loss: 0.5772 - mae: 0.1463 - mse: 0.0341 - val_loss: 0.5768 - val_mae: 0.1457 - val_mse: 0.0335 - lr: 3.2200e-04
# Epoch 6/20
# ...

# %%
def extract_weights(name, model):
    # Get the layer by name from the model
    weight_layer = model.get_layer(name)

    # Get the weights from the layer
    weights = weight_layer.get_weights()[0]

    # Normalize the weights
    weights = weights / np.linalg.norm(weights, axis=1).reshape((-1, 1))

    return weights

# Extract weights for anime embeddings
manga_weights = extract_weights('manga_embedding', model)
# Extract weights for user embeddings
user_weights = extract_weights('user_embedding', model)

# %%
popularity_threshold = 50
df_manga= df_manga.query('Members >= @popularity_threshold')
print(df_manga.shape)
df_manga.head(3)      # only give rating of those mangas for which atleast 200 user have rated
# Out:
# (22879, 24)
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
#
#        Other name Score                         Genres  \
# 0       カウボーイビバップ  8.75  Action, Award Winning, Sci-Fi
# 1  カウボーイビバップ 天国の扉  8.38                 Action, Sci-Fi
# 2           トライガン  8.22      Action, Adventure, Sci-Fi
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
#
#                          Aired  ...   Studios    Source       Duration  \
# 0  Apr 3, 1998 to Apr 24, 1999  ...   Sunrise  Original  24 min per ep
# ...

# %%
#df_manga['Main_series'] = df_manga['English name'].apply(lambda x: re.split(r'[:Season ]', x)[0])

#values_to_drop = ['Movie', 'OVA', 'Special', 'ONA', 'Music', 'Unknown']

#df_manga = df_manga[~df_manga['Type'].isin(values_to_drop)]

# Define words/phrases to remove
#remove_words = [
#'Season 2', 'Final Season', 'Season 3', 'Season 4', 'Season 5',
#'Season 6', '3rd Season', 'Second Season', '2nd Season','Part 2', 'R2'
#]

# Create regex pattern
#pattern = '|'.join(remove_words)

# Remove words/phrases from 'English name'
#df_manga['English name'] = df_manga['English name'].str.replace(pattern, '', regex=True).str.strip()

#values_to_drop2 = ['Unknown','UNKNOWN']

#df_manga = df_manga[~df_manga['English name'].isin(values_to_drop2)]

# %%
def find_similar_mangas(name, n=10, return_dist=False, neg=False):
    try:
        manga_row = df_manga[df_manga['Name'] == name].iloc[0]
        index = manga_row['anime_id']
        encoded_index = manga_encoder.transform([index])[0]
        weights = manga_weights
        dists = np.dot(weights, weights[encoded_index])
        sorted_dists = np.argsort(dists)
        n = n + 1
        if neg:
            closest = sorted_dists[:n]
        else:
            closest = sorted_dists[-n:]
        print('Manga closest to {}'.format(name))
        if return_dist:
            return dists, closest

        SimilarityArr = []

        for close in closest:
            decoded_id = manga_encoder.inverse_transform([close])[0]
            manga_frame = df_manga[df_manga['anime_id'] == decoded_id]
            manga_name = manga_frame['Name'].values[0]
            english_name = manga_frame['English name'].values[0]
            name = english_name if english_name != "UNKNOWN" else manga_name
            genre = manga_frame['Genres'].values[0]
            similarity = dists[close]
            similarity = "{:.2f}%".format(similarity * 100)
            SimilarityArr.append({"Name": name, "Similarity": similarity, "Genres": genre,})
        Frame = pd.DataFrame(SimilarityArr).sort_values(by="Similarity", ascending=False)
        return Frame[Frame.Name != name]
    except:
        print('{} not found in Manga list'.format(name))

pd.set_option('display.max_colwidth', None)

# %%
#examples

# %%
find_similar_mangas('Hunter x Hunter', n=5, neg=False)
# Out:
# Manga closest to Hunter x Hunter
#                                         Name Similarity  \
# 4  Hunter x Hunter: Original Video Animation     92.19%
# 3        Hunter x Hunter: Greed Island Final     91.96%
# 2              Hunter x Hunter: Greed Island     91.57%
# 1                            Fighting Spirit     63.56%
#
#                        Genres
# 4  Action, Adventure, Fantasy
# 3  Action, Adventure, Fantasy
# 2  Action, Adventure, Fantasy
# 1                      Sports

# %%
find_similar_mangas('Soul Eater', n=7, neg=False)
# Out:
# Manga closest to Soul Eater
#                                  Name Similarity  \
# 6                       Blue Exorcist     60.25%
# 5                          D.Gray-man     58.06%
# 4         Ouran High School Host Club     57.56%
# 3                        Black Butler     55.29%
# 2                      Lovely Complex     54.44%
# 1  Final Fantasy VII: Advent Children     53.90%
# 0                             Reborn!     53.89%
#
#                                   Genres
# 6                        Action, Fantasy
# 5             Action, Adventure, Fantasy
# 4                        Comedy, Romance
# 3  Action, Comedy, Mystery, Supernatural
# 2                        Comedy, Romance
# 1                        Action, Fantasy
# 0                         Action, Comedy

# %% [markdown]
# # **User-Based Recommender**

# %%
# I am trying to randomly find a user and find a similar user

# %%
def find_similar_users(item_input, n=10, return_dist=False, neg=False):
    try:
        index = item_input
        encoded_index = user_encoder.transform([index])[0]
        weights = user_weights
        dists = np.dot(weights, weights[encoded_index])
        sorted_dists = np.argsort(dists)
        n = n + 1

        if neg:
            closest = sorted_dists[:n]
        else:
            closest = sorted_dists[-n:]

        SimilarityArr = []

        for close in closest:
            similarity = dists[close]
            if isinstance(item_input, int):
                decoded_id = user_encoder.inverse_transform([close])[0]
                SimilarityArr.append({"similar_users": decoded_id, "similarity": similarity})
        Frame = pd.DataFrame(SimilarityArr).sort_values(by="similarity", ascending=False)
        return Frame
    except:
        print('\033[1m{}\033[0m, Not Found in User list'.format(item_input))

# %%
# Select a random user
ratings_per_user = df_score.groupby('user_id').size()
random_user = int(ratings_per_user[ratings_per_user < 500].sample(1, random_state=None).index[0])

# Find similar users to the random user
similar_users = find_similar_users(random_user, n=10, neg=False)
similar_users = similar_users[similar_users.similarity > 0.4]
similar_users = similar_users[similar_users.similar_users != random_user]
similar_users
# Out:
#    similar_users  similarity
# 9         417331    0.522848
# 8         404610    0.484444
# 7        1199597    0.454838
# 6        1213619    0.451885
# 5         366744    0.451185
# 4         448630    0.446054
# 3         318616    0.444823
# 2           7910    0.444254
# 1         430438    0.444053
# 0        1128779    0.442959

# %%
# Function to display a word cloud of preferred genres
def showWordCloud(all_genres):
    genres_cloud = WordCloud(width=700, height=400, background_color='white', colormap='gnuplot').generate_from_frequencies(all_genres)
    plt.figure(figsize=(10, 8))
    plt.imshow(genres_cloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

def get_user_preferences(user_id, plot=False, verbose=0):
    manga_read_by_user = df_score[df_score['user_id'] == user_id]

    if manga_read_by_user.empty:
        print("User #{} has not read any mangas.".format(user_id))
        return pd.DataFrame()

    user_rating_percentile = np.percentile(manga_read_by_user.rating, 75)
    manga_read_by_user = manga_read_by_user[manga_read_by_user.rating >= user_rating_percentile]
    top_manga_user = (
        manga_read_by_user.sort_values(by="rating", ascending=False)
        .anime_id.values
    )

    manga_df_rows = df_manga[df_manga["anime_id"].isin(top_manga_user)]
    manga_df_rows = manga_df_rows[["Name", "Genres"]]

    if verbose != 0:
        print("User \033[1m{}\033[0m has read {} manga(s) with an average rating of {:.1f}/10\n".format(
            user_id, len(manga_read_by_user), manga_read_by_user['rating'].mean()
        ))
        print('\033[1m----- Preferred genres----- \033[0m\n')

    if plot:
        genres_list = []
        for genres in manga_df_rows['Genres']:
            if isinstance(genres, str):
                for genre in genres.split(','):
                    genres_list.append(genre.strip())

        showWordCloud(dict(Counter(genres_list)))

    return manga_df_rows

# %%
# Get user preferences for the random user
#user_pref = get_user_preferences(random_user, plot=True, verbose=1)
#pd.DataFrame(user_pref).head(5)

# %%
def get_recommended_manga(similar_users, user_pref, n=10):
    recommended_manga = []
    manga_list = []

    for user_id in similar_users.similar_users.values:
        pref_list = get_user_preferences(int(user_id))
        if not pref_list.empty:  # Check if user has read any manga
            pref_list = pref_list[~pref_list["Name"].isin(user_pref["Name"].values)]
            manga_list.append(pref_list.Name.values)

    if len(manga_list) == 0:
        print("No manga recommendations available for the given users.")
        return pd.DataFrame()

    manga_list = pd.DataFrame(manga_list)
    sorted_list = pd.DataFrame(pd.Series(manga_list.values.ravel()).value_counts()).head(n)
    # Count the occurrences of each anime in the entire dataset
    manga_count = df_score['anime_id'].value_counts()

    for i, anime_name in enumerate(sorted_list.index):
        if isinstance(anime_name, str):
            try:
                anime_id = df_manga[df_manga.Name == anime_name].anime_id.values[0]
                english_name = df_manga[df_manga['Name'] == anime_name]['English name'].values[0]
                name = english_name if english_name != "UNKNOWN" else anime_name
                genre = df_manga[df_manga.Name == anime_name].Genres.values[0]
                n_user_pref = manga_count.get(anime_id, 0)  # Get the total count of users who have watched this anime
                recommended_manga.append({
                    "n": n_user_pref,
                    "manga_name": anime_name,
                    "Genres": genre,
                })
            except:
                pass
    return pd.DataFrame(recommended_manga)

# %%
# Get recommended mangas for random user based on similiar users
recommended_manga = get_recommended_manga(similar_users, user_pref, n=10)

print('\n> Top recommendations for user: {}'.format(random_user))
recommended_manga
# Out:
# > Top recommendations for user: 360187
#         n                                                manga_name  \
# 0  126492                                                Death Note
# 1   45719                                        Shingeki no Kyojin
# 2   93001                                       Fullmetal Alchemist
# 3   76710                          Fullmetal Alchemist: Brotherhood
# 4   82329                        Code Geass: Hangyaku no Lelouch R2
# 5   70360                                              Angel Beats!
# 6   51651                                      Clannad: After Story
# 7   68220                                                   Clannad
# 8   51317                                                 One Piece
# 9   46304  Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.
#
#                                              Genres
# 0                            Supernatural, Suspense
# 1            Action, Award Winning, Drama, Suspense
# ...
